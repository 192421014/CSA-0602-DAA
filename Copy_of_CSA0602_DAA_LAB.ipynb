# %% [markdown]
# <a href="https://colab.research.google.com/github/192421014/CSA-0602-DAA/blob/main/Copy_of_CSA0602_DAA_LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of elements: "))
arr = []
print("Enter elements:")
for i in range(n):
    arr.append(int(input()))
key = int(input("Enter key to search: "))
found = False
for i in range(n):
    if arr[i] == key:
        print("Key found at index", i)
        found = True
        break
if not found:
    print("Key not found")
# Out:
# Enter number of elements: 5
# Enter elements:
# 10
# 20
# 30
# 40
# 50
# Enter key to search: 30
# Key found at index 2

# %%
def binary_search(arr, low, high, key):
    if low <= high:
        mid = (low + high)
        if arr[mid] == key:
            return mid
        elif key < arr[mid]:
            return binary_search(arr, low, mid - 1, key)
        else:
            return binary_search(arr, mid + 1, high, key)
    return -1
n = int(input("Enter number of elements: "))
arr = []
print("Enter sorted elements:")
for i in range(n):
    arr.append(int(input()))
key = int(input("Enter key to search: "))
result = binary_search(arr, 0, n - 1, key)
if result != -1:
    print("Key found at index", result)
else:
    print("Key not found")
# Out:
# Enter number of elements: 5
# Enter sorted elements:
# 5
# 10
# 15
# 20
# 25
# Enter key to search: 15
# Key found at index 2

# %%
def iterative_factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
def recursive_factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * recursive_factorial(n - 1)
n = int(input("Enter a number: "))
print("Iterative Factorial =", iterative_factorial(n))
print("Recursive Factorial =", recursive_factorial(n))
# Out:
# Enter a number: 5
# Iterative Factorial = 120
# Recursive Factorial = 120

# %%
def iterative_fibonacci(n):
    a = 0
    b = 1
    print("Iterative Fibonacci Series:")
    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b
def recursive_fibonacci(n):
    if n <= 1:
        return n
    return recursive_fibonacci(n - 1) + recursive_fibonacci(n - 2)
n = int(input("Enter number of terms: "))
iterative_fibonacci(n)
print("\nRecursive Fibonacci Series:")
for i in range(n):
    print(recursive_fibonacci(i), end=" ")
# Out:
# Enter number of terms: 8
# Iterative Fibonacci Series:
# 0 1 1 2 3 5 8 13
# Recursive Fibonacci Series:
# 0 1 1 2 3 5 8 13

# %%
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))
print("Enter First Matrix:")
A = []
for i in range(rows):
    row = []
    for j in range(cols):
        row.append(int(input()))
    A.append(row)
print("Enter Second Matrix:")
B = []
for i in range(rows):
    row = []
    for j in range(cols):
        row.append(int(input()))
    B.append(row)
result = []
for i in range(rows):
    row = []
    for j in range(cols):
        row.append(0)
    result.append(row)
for i in range(rows):
    for j in range(cols):
        for k in range(cols):
            result[i][j] += A[i][k] * B[k][j]
print("Result Matrix:")
for row in result:
    print(row)
# Out:
# Enter number of rows: 2
# Enter number of columns: 2
# Enter First Matrix:
# 1
# 1
# 2
# 2
# Enter Second Matrix:
# 3
# 3
# 4
# 4
# Result Matrix:
# [7, 7]
# [14, 14]

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]
        merge_sort(left)
        merge_sort(right)
        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1
n = int(input("Enter the number of elements: "))
arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))

print("Original Array:", arr)
merge_sort(arr)
print("Sorted Array:", arr)
print("\nTime Complexity:")
print("Best Case   : O(n log n)")
print("Average Case: O(n log n)")
print("Worst Case  : O(n log n)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of elements: 7
# Enter the elements:
# 38
# 27
# 3
# 45
# 97
# 68
# 20
# Original Array: [38, 27, 3, 45, 97, 68, 20]
# Sorted Array: [3, 20, 27, 38, 45, 68, 97]
#
# Time Complexity:
# Best Case   : O(n log n)
# Average Case: O(n log n)
# Worst Case  : O(n log n)
# Space Complexity: O(n)

# %%
# Experiment 7: Quick Sort

def quick_sort(arr, low, high):
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)
def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1
n = int(input("Enter the number of elements: "))
arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))
print("Original Array:", arr)
quick_sort(arr, 0, n - 1)
print("Sorted Array:", arr)
print("\nTime Complexity:")
print("Best Case   : O(n log n)")
print("Average Case: O(n log n)")
print("Worst Case  : O(n^2)")
print("Space Complexity: O(log n)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 25
# 5
# 6
# 7
# 1
# Original Array: [25, 5, 6, 7, 1]
# Sorted Array: [1, 5, 6, 7, 25]
#
# Time Complexity:
# Best Case   : O(n log n)
# Average Case: O(n log n)
# Worst Case  : O(n^2)
# Space Complexity: O(log n)

# %%
# Experiment 8: Tower of Hanoi

def tower_of_hanoi(n, source, auxiliary, destination):
    if n == 1:
        print("Move disk 1 from", source, "to", destination)
        return
    tower_of_hanoi(n - 1, source, destination, auxiliary)
    print("Move disk", n, "from", source, "to", destination)
    tower_of_hanoi(n - 1, auxiliary, source, destination)
n = int(input("Enter the number of disks: "))
print("\nSequence of moves:")
tower_of_hanoi(n, 'A', 'B', 'C')
print("\nTime Complexity: O(2^n)")
print("Space Complexity: O(n)")
# Out:
# Enter the number of disks: 3
#
# Sequence of moves:
# Move disk 1 from A to C
# Move disk 2 from A to B
# Move disk 1 from C to B
# Move disk 3 from A to C
# Move disk 1 from B to A
# Move disk 2 from B to C
# Move disk 1 from A to C
#
# Time Complexity: O(2^n)
# Space Complexity: O(n)

# %%
# Experiment 9: GCD (Euclidean Algorithm)

def gcd(a, b):
    if b == 0:
        return a
    return gcd(b, a % b)
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
result = gcd(a, b)
print("GCD of", a, "and", b, "is:", result)
print("\nTime Complexity: O(log n)")
print("Space Complexity: O(log n)")
# Out:
# Enter first number: 48
# Enter second number: 18
# GCD of 48 and 18 is: 6
#
# Time Complexity: O(log n)
# Space Complexity: O(log n)

# %%
# Experiment 10: Insertion Sort
n = int(input("Enter the number of elements: "))
arr = []
print("Enter the elements:")
for i in range(n):
    arr.append(int(input()))
print("Original Array:", arr)
for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -=
    arr[j + 1] = key
print("Sorted Array:", arr)
print("\nTime Complexity:")
print("Best Case   : O(n)")
print("Average Case: O(n^2)")
print("Worst Case  : O(n^2)")
print("Space Complexity: O(1)")
# Out:
# Enter the number of elements: 5
# Enter the elements:
# 12
# 23
# 45
# 65
# 76
# Original Array: [12, 23, 45, 65, 76]
# Sorted Array: [12, 23, 45, 65, 76]
#
# Time Complexity:
# Best Case   : O(n)
# Average Case: O(n^2)
# Worst Case  : O(n^2)
# Space Complexity: O(1)

# %%
# Experiment  11
def heapify(arr, n, i):
    largest = i
    left = 2 * i + 1
    right = 2 * i + 2
    if left < n and arr[left] > arr[largest]:
        largest = left
    if right < n and arr[right] > arr[largest]:
        largest = right
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)
def heap_sort(arr):
    n = len(arr)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
    for i in range(n - 1, 0, -1):
        arr[0], arr[i] = arr[i], arr[0]
        heapify(arr, i, 0)
arr = list(map(int, input("Enter array elements: ").split()))
heap_sort(arr)
print("Sorted array:", arr)
# Out:
# Enter array elements: 4 10 3 5 1
# Sorted array: [1, 3, 4, 5, 10]

# %%
def merge_and_count(arr, temp, left, mid, right):
    i = left
    j = mid + 1
    k = left
    inversions = 0
    while i <= mid and j <= right:
        if arr[i] <= arr[j]:
            temp[k] = arr[i]
            i += 1
        else:
            temp[k] = arr[j]
            inversions += mid - i + 1
            j += 1
        k += 1
    while i <= mid:
        temp[k] = arr[i]
        i += 1
        k += 1
    while j <= right:
        temp[k] = arr[j]
        j += 1
        k += 1
    for i in range(left, right + 1):
        arr[i] = temp[i]
    return inversions
def count_inversions(arr, temp, left, right):
    inversions = 0
    if left < right:
        mid = (left + right) // 2
        inversions += count_inversions(arr, temp, left, mid)
        inversions += count_inversions(arr, temp, mid + 1, right)
        inversions += merge_and_count(arr, temp, left, mid, right)
    return inversions
arr = list(map(int, input("Enter array elements: ").split()))
temp = [0] * len(arr)
result = count_inversions(arr, temp, 0, len(arr) - 1)
print("Number of inversions:", result)
# Out:
# Enter array elements: 2 4 1 3 5
# Number of inversions: 3

# %%
# Experiment 13
def crossing_sum(arr, left, mid, right):
    total = 0
    left_sum = float("-inf")

    for i in range(mid, left - 1, -1):
        total += arr[i]
        left_sum = max(left_sum, total)

    total = 0
    right_sum = float("-inf")

    for i in range(mid + 1, right + 1):
        total += arr[i]
        right_sum = max(right_sum, total)

    return left_sum + right_sum


def maximum_subarray(arr, left, right):
    if left == right:
        return arr[left]

    mid = (left + right) // 2

    return max(
        maximum_subarray(arr, left, mid),
        maximum_subarray(arr, mid + 1, right),
        crossing_sum(arr, left, mid, right)
    )


arr = list(map(int, input("Enter array elements: ").split()))

result = maximum_subarray(arr, 0, len(arr) - 1)

print("Maximum subarray sum:", result)
# Out:
# Enter array elements: -2 -3 4 -1 -2 1 5 -3
# Maximum subarray sum: 7

# %%
# Experiment 14
def iterative_power(x, n):
    result = 1

    for i in range(n):
        result *= x

    return result


x = int(input("Enter the base value: "))
n = int(input("Enter the exponent value: "))

print("Result using iterative method:", iterative_power(x, n))
# Out:
# Enter the base value: 2
# Enter the exponent value: 10
# Result using iterative method: 1024

# %%
# exp 15
import math


def closest_pair(points):
    minimum_distance = float("inf")
    closest_points = None

    for i in range(len(points)):
        for j in range(i + 1, len(points)):
            x1, y1 = points[i]
            x2, y2 = points[j]

            distance = math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

            if distance < minimum_distance:
                minimum_distance = distance
                closest_points = (points[i], points[j])

    return closest_points, minimum_distance


n = int(input("Enter the number of points: "))
points = []

for i in range(n):
    x, y = map(int, input(f"Enter point {i + 1} (x y): ").split())
    points.append((x, y))

pair, distance = closest_pair(points)

print("Closest pair:", pair[0], "-", pair[1])
print("Distance:", distance)
# Out:
# Enter the number of points: 4
# Enter point 1 (x y): 1 2
# Enter point 2 (x y): 4 5
# Enter point 3 (x y): 7 8
# Enter point 4 (x y): 3 1
# Closest pair: (1, 2) - (3, 1)
# Distance: 2.23606797749979

# %%
# TOPIC 2

# %%
 # slection
 def top_k_scores(scores, k):
    arr = scores[:]
    n = len(arr)
    if k > n:
        k = n
    for i in range(k):
        max_index = i
        for j in range(i + 1, n):
            if arr[j] > arr[max_index]:
                max_index = j
        arr[i], arr[max_index] = arr[max_index], arr[i]
    return arr[:k]
scores = list(map(int, input("Enter the participant scores: ").split()))
k = int(input("Enter the value of k: "))
print("Top", k, "scores:", top_k_scores(scores, k))
# Out:
# Enter the participant scores:  75 80 95 85 69 74 30 60 70
# Enter the value of k: 5
# Top 5 scores: [95, 85, 80, 75, 74]

# %%
# memory
def selection_sort_min_writes(arr):
    arr = arr[:]
    n = len(arr)
    swaps = 0
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        if min_index != i:
            arr[i], arr[min_index] = arr[min_index], arr[i]
            swaps += 1
    return arr, swaps
arr = list(map(float, input("Enter the temperature readings: ").split()))
sorted_arr, swap_count = selection_sort_min_writes(arr)
print("Sorted readings:", sorted_arr)
print("Number of swaps:", swap_count)
print("Maximum allowed swaps:", max(0, len(sorted_arr) - 1))
# Out:
# Enter the temperature readings: 23.5 19.2 25.1 18.8 21.4
# Sorted readings: [18.8, 19.2, 21.4, 23.5, 25.1]
# Number of swaps: 2
# Maximum allowed swaps: 4

# %%
# lib
def reorder_shelf(books):
    arr = books[:]
    n = len(arr)
    moves = 0
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        if min_index != i:
            arr[i], arr[min_index] = arr[min_index], arr[i]
            moves += 1
    return arr, moves
books = list(map(int, input("Enter the book IDs: ").split()))
ordered, moves = reorder_shelf(books)
print("Ordered shelf:", ordered)
print("Physical moves (swaps):", moves)
# Out:
# Enter the book IDs: 305 102 250 118 199 400 101
# Ordered shelf: [101, 102, 118, 199, 250, 305, 400]
# Physical moves (swaps): 4

# %%
# contest
def distribute_prizes(participants):
    arr = participants[:]
    n = len(arr)
    for i in range(n):
        max_index = i
        for j in range(i + 1, n):
            if arr[j][1] > arr[max_index][1]:
                max_index = j
        arr[i], arr[max_index] = arr[max_index], arr[i]
    return arr
n = int(input("Enter the number of participants: "))
participants = []
for i in range(n):
    name = input("Enter participant name: ")
    score = int(input("Enter participant score: "))
    participants.append((name, score))
ranking = distribute_prizes(participants)
print("\nPrize Distribution (Ranking):")
for i, (name, score) in enumerate(ranking, start=1):
    print(f"{i}. {name} - {score}")
# Out:
# Enter the number of participants: 3
# Enter participant name: AHILAN R
# Enter participant score: 95
# Enter participant name: YUVA
# Enter participant score: 20
# Enter participant name: GOKUL
# Enter participant score: 90
#
# Prize Distribution (Ranking):
# 1. AHILAN R - 95
# 2. GOKUL  - 90
# 3. YUVA - 20

# %%
#SMALL DATA
import time
def selection_sort(arr):
    arr = arr[:]
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        if min_index != i:
            arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr
prices = list(map(int, input("Enter the item prices: ").split()))
start = time.perf_counter()
sorted_prices = selection_sort(prices)
end = time.perf_counter()
print("Sorted prices:", sorted_prices)
print("Execution time:", (end - start) * 1000000, "microseconds")
# Out:
# Enter the item prices:  499 399 299 599 749 859
# Sorted prices: [299, 399, 499, 599, 749, 859]
# Execution time: 83.01200023197453 microseconds

# %%
#EXAM
def optimized_bubble_sort(arr):
    n = len(arr)
    passes = 0
    for i in range(n - 1):
        swapped = False
        passes += 1
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr, passes
sorted_rolls, passes = optimized_bubble_sort([101,102,104,103,105,107,106,108])
assert sorted_rolls == sorted([101,102,104,103,105,107,106,108])
assert passes < 8
sorted_ok, passes_ok = optimized_bubble_sort([1,2,3,4,5])
assert passes_ok == 1
print("Sorted Roll Numbers:", sorted_rolls)
print("Passes:", passes)
print("All test cases passed!")
# Out:
# Sorted Roll Numbers: [101, 102, 103, 104, 105, 106, 107, 108]
# Passes: 2
# All test cases passed!

# %%
def bubble_sort_queue(queue):
    priority = {
        "ambulance": 1,
        "bus": 2,
        "car": 3
    }
    n = len(queue)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if priority[queue[j]] > priority[queue[j + 1]]:
                queue[j], queue[j + 1] = queue[j + 1], queue[j]
    return queue
queue = ['car', 'car', 'bus']
queue.append('ambulance')
result = bubble_sort_queue(queue)
assert result == ['ambulance', 'bus', 'car', 'car']
print("Priority Queue:", result)
print("All test cases passed!")
# Out:
# Priority Queue: ['ambulance', 'bus', 'car', 'car']
# All test cases passed!

# %%
#BUBBLE
def bubble_sort_with_frames(arr):
    frames = [arr.copy()]
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
        frames.append(arr.copy())
    return frames
frames = bubble_sort_with_frames([5, 1, 4, 2, 8])
assert frames[-1] == sorted([5, 1, 4, 2, 8])
assert frames[0] == [5, 1, 4, 2, 8]
assert len(frames) >= 2
print("Frames:")
for f in frames:
    print(f)
print("All test cases passed!")
# Out:
# Frames:
# [5, 1, 4, 2, 8]
# [1, 4, 2, 5, 8]
# [1, 2, 4, 5, 8]
# [1, 2, 4, 5, 8]
# [1, 2, 4, 5, 8]
# All test cases passed!

# %%
#SORTING SENSOR
def bubble_sort_plain(arr):
    arr = arr.copy()
    n = len(arr)
    comparisons = 0
    for i in range(n - 1):
        for j in range(n - i - 1):
            comparisons += 1
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr, comparisons
def bubble_sort_optimized(arr):
    arr = arr.copy()
    n = len(arr)
    comparisons = 0
    for i in range(n - 1):
        swapped = False
        for j in range(n - i - 1):
            comparisons += 1
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr, comparisons
alerts = [2,1,3,2,1,4,3,2,5,1,2,3,4,1,2]
r1, c1 = bubble_sort_plain(alerts)
r2, c2 = bubble_sort_optimized(alerts)
assert r1 == r2 == sorted(alerts)
assert c2 <= c1
print("Plain comparisons:", c1)
print("Optimized comparisons:", c2)
print("All test cases passed!")
# Out:
# Plain comparisons: 105
# Optimized comparisons: 99
# All test cases passed!

# %%
#CARD GAME
def bubble_sort_hand(arr):
    arr = arr.copy()
    n = len(arr)
    passes = 0
    for i in range(n - 1):
        swapped = False
        passes += 1
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break
    return arr, passes
hand = [2, 4, 6, 8, 9, 11, 13]
hand.append(7)
final_hand, passes_incremental = bubble_sort_hand(hand)
assert final_hand == sorted(hand)
import random
shuffled = hand.copy()
random.shuffle(shuffled)
_, passes_full = bubble_sort_hand(shuffled)
assert passes_incremental <= passes_full
print("Incremental Passes:", passes_incremental)
print("Full Sort Passes:", passes_full)
print("All test cases passed!")
# Out:
# Incremental Passes: 5
# Full Sort Passes: 6
# All test cases passed!

# %%
#LIVE LEADER
def insert_updated_score(board, score):
    board = board.copy()
    board.append(score)
    shifts = 0
    i = len(board) - 2
    while i >= 0 and board[i] < score:
        board[i + 1] = board[i]
        shifts += 1
        i -= 1
    board[i + 1] = score
    return board, shifts
board = [980, 875, 760, 690, 500]
updated_board, shifts = insert_updated_score(board, 820)
assert updated_board == [980, 875, 820, 760, 690, 500]
board2, shifts2 = insert_updated_score(board, 100)
assert board2[-1] == 100 and shifts2 == 0
print("All test cases passed!")
# Out:
# All test cases passed!

# %%
#CARD SORTING
def pick_up_card(hand, card):
    hand = hand.copy()
    hand.append(card)
    i = len(hand) - 2
    while i >= 0 and hand[i] > card:
        hand[i + 1] = hand[i]
        i -= 1
    hand[i + 1] = card
    return hand
hand = []
for card in [7, 2, 9, 4, 1]:
    hand = pick_up_card(hand, card)
assert hand == sorted([7, 2, 9, 4, 1])
assert pick_up_card([], 5) == [5]
print("All test cases passed!")
# Out:
# All test cases passed!

# %%
# REAL TIME STOCK
def insert_price(prices, price):
    prices = prices.copy()
    prices.append(price)
    i = len(prices) - 2
    while i >= 0 and prices[i] > price:
        prices[i + 1] = prices[i]
        i -= 1
    prices[i + 1] = price
    return prices
prices = []
for p in [102.5, 98.3, 105.1, 100.0, 97.8]:
    prices = insert_price(prices, p)
assert prices == sorted([102.5, 98.3, 105.1, 100.0, 97.8])
assert prices[0] == min(prices)
assert prices[-1] == max(prices)
print("All test cases passed!")
# Out:
# All test cases passed!

# %%
#PLAYSIST RECORDER
def insert_song(playlist, song):
    playlist = playlist.copy()
    playlist.append(song)
    i = len(playlist) - 2
    while i >= 0 and playlist[i][1] > song[1]:
        playlist[i + 1] = playlist[i]
        i -= 1
    playlist[i + 1] = song
    return playlist
playlist = [('Intro', 120), ('Chill Beat', 210), ('Long Jam', 340)]
updated_playlist = insert_song(playlist, ('Quick Track', 180))
durations = [s[1] for s in updated_playlist]
assert durations == sorted([120, 210, 340, 180])
assert ('Quick Track', 180) in updated_playlist
print("All test cases passed!")
# Out:
# All test cases passed!

# %%
#NEARLY SORTED ALG
def insertion_sort_count_shifts(arr):
    arr = arr.copy()
    shifts = 0
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            shifts += 1
            j -= 1
        arr[j + 1] = key
    return arr, shifts
log = [18.2, 18.5, 18.9, 17.9, 19.1, 19.4, 19.0]
sorted_log, shifts_nearly = insertion_sort_count_shifts(log)
assert sorted_log == sorted(log)
import random
shuffled_log = log.copy()
random.shuffle(shuffled_log)
_, shifts_random = insertion_sort_count_shifts(shuffled_log)
print("Nearly-sorted shifts:", shifts_nearly)
print("Random shifts:", shifts_random)
print("All test cases passed!")
# Out:
# Nearly-sorted shifts: 5
# Random shifts: 7
# All test cases passed!
